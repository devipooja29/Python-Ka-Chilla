# %% [markdown]
# ### Plotting in python
# by Pooja Dinani

# %%
# Import libraries

import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset

kashti = sns.load_dataset('titanic')
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti.survived.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='survived'>

# %%
sns.countplot(x="survived", hue="sex", data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
plt.scatter(x="age", y="fare", c="pclass", data=kashti, label="Pclass")

# %%
sns.scatterplot(x="age", y="fare", hue="pclass", data=kashti)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.barplot(x="sex", y="fare", hue="pclass", data=kashti)
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.pairplot(kashti)

# %%
kashti.hist(bins=10, figsize=(9,7), grid=False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
sns.boxplot(x="sex", y="fare", hue="embark_town", data=kashti)
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxenplot(x="sex", y="fare", hue="embark_town", data=kashti)
plt.xlabel("Sex")
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')

# %%
g = sns.FacetGrid(kashti, hue="survived", col="who", margin_titles=True,
                  palette={1:"seagreen", 0:"gray"})
g = g.map(plt.scatter, "fare", "age", edgecolor="w").add_legend();

# %%
sns.stripplot(x="sex", y="fare", hue="class", data=kashti)
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    category
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(3), float64(2), int64(4), object(4)
# memory usage: 74.7+ KB

# %%
kashti.sample(100)
# Out:
#      survived  pclass sex   age  sibsp  parch      fare embarked  class  \
# 484         1       1   0  25.0      1      0   91.0792        C  First
# 737         1       1   0  35.0      0      0  512.3292        C  First
# 246         0       3   1  25.0      0      0    7.7750        S  Third
# 588         0       3   0  22.0      0      0    8.0500        S  Third
# 336         0       1   0  29.0      1      0   66.6000        S  First
# ..        ...     ...  ..   ...    ...    ...       ...      ...    ...
# 31          1       1   1   NaN      1      0  146.5208        C  First
# 724         1       1   0  27.0      1      0   53.1000        S  First
# 167         0       3   1  45.0      1      4   27.9000        S  Third
# 806         0       1   0  39.0      0      0    0.0000        S  First
# 548         0       3   0  33.0      1      1   20.5250        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
numeric_columns = kashti.select_dtypes(include=['number']).columns
corr = kashti[numeric_columns].corr()

plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.violinplot(x="survived", y="fare", hue="class", data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='fare'>
