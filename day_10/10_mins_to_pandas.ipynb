# %% [markdown]
# ## 10 Minutes to Pandas
# Written by: Pooja Dinani\
# Email: piyadinani@gmail.com\
# Date: 18/11/2023

# %%
# Importing libraries
import numpy as np
import pandas as pd

# %%
# Object creation with default RangeIndex
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# Object creation with datetime index using date_range()
dates = pd.date_range("20131118", periods=6)
dates
# Out:
# DatetimeIndex(['2013-11-18', '2013-11-19', '2013-11-20', '2013-11-21',
#                '2013-11-22', '2013-11-23'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-11-18 -2.449298  1.961739  0.016516  1.066031
# 2013-11-19  1.209363  1.659395 -0.414144 -0.254825
# 2013-11-20  1.177539 -0.094514  0.963315  2.367925
# 2013-11-21  0.648059  0.799593  0.483620  0.382270
# 2013-11-22  0.734520  0.398593  0.057050 -1.288149
# 2013-11-23  0.481939 -0.686211 -0.074445  0.516233

# %%
# Object creation by passing dictionary (Key (Column name), Value (Column Value))
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20231118"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2023-11-18  1.0  3   test  foo
# 1  1.0 2023-11-18  1.0  3  train  foo
# 2  1.0 2023-11-18  1.0  3   test  foo
# 3  1.0 2023-11-18  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
# Viewing data
df.head()
# Out:
#                    A         B         C         D
# 2013-11-18 -2.449298  1.961739  0.016516  1.066031
# 2013-11-19  1.209363  1.659395 -0.414144 -0.254825
# 2013-11-20  1.177539 -0.094514  0.963315  2.367925
# 2013-11-21  0.648059  0.799593  0.483620  0.382270
# 2013-11-22  0.734520  0.398593  0.057050 -1.288149

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2013-11-19  1.209363  1.659395 -0.414144 -0.254825
# 2013-11-20  1.177539 -0.094514  0.963315  2.367925
# 2013-11-21  0.648059  0.799593  0.483620  0.382270
# 2013-11-22  0.734520  0.398593  0.057050 -1.288149
# 2013-11-23  0.481939 -0.686211 -0.074445  0.516233

# %%
df.index
# Out:
# DatetimeIndex(['2013-11-18', '2013-11-19', '2013-11-20', '2013-11-21',
#                '2013-11-22', '2013-11-23'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# NumPy representation of the data
df.to_numpy()
# Out:
# array([[-2.4492983 ,  1.96173939,  0.01651636,  1.06603136],
#        [ 1.2093626 ,  1.65939548, -0.41414394, -0.25482515],
#        [ 1.17753859, -0.0945138 ,  0.96331527,  2.36792457],
#        [ 0.64805925,  0.79959287,  0.48361993,  0.38227019],
#        [ 0.73452005,  0.39859275,  0.05704983, -1.28814897],
#        [ 0.48193884, -0.68621109, -0.07444528,  0.51623311]])

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2023-11-18 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2023-11-18 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2023-11-18 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2023-11-18 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.300354  0.673099  0.171985  0.464914
# std    1.378311  1.016040  0.482696  1.231544
# min   -2.449298 -0.686211 -0.414144 -1.288149
# 25%    0.523469  0.028763 -0.051705 -0.095551
# 50%    0.691290  0.599093  0.036783  0.449252
# 75%    1.066784  1.444445  0.376977  0.928582
# max    1.209363  1.961739  0.963315  2.367925

# %%
df.T
# Out:
#    2013-11-18  2013-11-19  2013-11-20  2013-11-21  2013-11-22  2013-11-23
# A   -2.449298    1.209363    1.177539    0.648059    0.734520    0.481939
# B    1.961739    1.659395   -0.094514    0.799593    0.398593   -0.686211
# C    0.016516   -0.414144    0.963315    0.483620    0.057050   -0.074445
# D    1.066031   -0.254825    2.367925    0.382270   -1.288149    0.516233

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-11-18  1.066031  0.016516  1.961739 -2.449298
# 2013-11-19 -0.254825 -0.414144  1.659395  1.209363
# 2013-11-20  2.367925  0.963315 -0.094514  1.177539
# 2013-11-21  0.382270  0.483620  0.799593  0.648059
# 2013-11-22 -1.288149  0.057050  0.398593  0.734520
# 2013-11-23  0.516233 -0.074445 -0.686211  0.481939

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-11-23  0.481939 -0.686211 -0.074445  0.516233
# 2013-11-20  1.177539 -0.094514  0.963315  2.367925
# 2013-11-22  0.734520  0.398593  0.057050 -1.288149
# 2013-11-21  0.648059  0.799593  0.483620  0.382270
# 2013-11-19  1.209363  1.659395 -0.414144 -0.254825
# 2013-11-18 -2.449298  1.961739  0.016516  1.066031

# %%
# Selection
df[["A", "B"]]
# Out:
#                    A         B
# 2013-11-18 -2.449298  1.961739
# 2013-11-19  1.209363  1.659395
# 2013-11-20  1.177539 -0.094514
# 2013-11-21  0.648059  0.799593
# 2013-11-22  0.734520  0.398593
# 2013-11-23  0.481939 -0.686211

# %%
df
# Out:
#                    A         B         C         D
# 2013-11-18 -2.449298  1.961739  0.016516  1.066031
# 2013-11-19  1.209363  1.659395 -0.414144 -0.254825
# 2013-11-20  1.177539 -0.094514  0.963315  2.367925
# 2013-11-21  0.648059  0.799593  0.483620  0.382270
# 2013-11-22  0.734520  0.398593  0.057050 -1.288149
# 2013-11-23  0.481939 -0.686211 -0.074445  0.516233

# %%
df.shape
# Out:
# (6, 4)

# %%
df.iloc[0:3, 0:3]
# Out:
#                    A         B         C
# 2013-11-18 -2.449298  1.961739  0.016516
# 2013-11-19  1.209363  1.659395 -0.414144
# 2013-11-20  1.177539 -0.094514  0.963315

# %%
df["20131118": "20131121"]
# Out:
#                    A         B         C         D
# 2013-11-18 -2.449298  1.961739  0.016516  1.066031
# 2013-11-19  1.209363  1.659395 -0.414144 -0.254825
# 2013-11-20  1.177539 -0.094514  0.963315  2.367925
# 2013-11-21  0.648059  0.799593  0.483620  0.382270

# %%
# Selection by label
df.loc[dates[0]]
# Out:
# A   -2.449298
# B    1.961739
# C    0.016516
# D    1.066031
# Name: 2013-11-18 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B", "C"]]
# Out:
#                    A         B         C
# 2013-11-18 -2.449298  1.961739  0.016516
# 2013-11-19  1.209363  1.659395 -0.414144
# 2013-11-20  1.177539 -0.094514  0.963315
# 2013-11-21  0.648059  0.799593  0.483620
# 2013-11-22  0.734520  0.398593  0.057050
# 2013-11-23  0.481939 -0.686211 -0.074445

# %%
df.loc["20131118": "20131121", ["A", "B"]]
# Out:
#                    A         B
# 2013-11-18 -2.449298  1.961739
# 2013-11-19  1.209363  1.659395
# 2013-11-20  1.177539 -0.094514
# 2013-11-21  0.648059  0.799593

# %%
df.loc[dates[1],"A"]
# Out:
# 1.2093626046789339

# %%
# Selection by position
df.iloc[3]
# Out:
# A    0.648059
# B    0.799593
# C    0.483620
# D    0.382270
# Name: 2013-11-21 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-11-21  0.648059  0.799593
# 2013-11-22  0.734520  0.398593

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-11-19  1.209363 -0.414144
# 2013-11-20  1.177539  0.963315
# 2013-11-22  0.734520  0.057050

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-11-19  1.209363  1.659395 -0.414144 -0.254825
# 2013-11-20  1.177539 -0.094514  0.963315  2.367925

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-11-18  1.961739  0.016516
# 2013-11-19  1.659395 -0.414144
# 2013-11-20 -0.094514  0.963315
# 2013-11-21  0.799593  0.483620
# 2013-11-22  0.398593  0.057050
# 2013-11-23 -0.686211 -0.074445

# %%
df.iloc[1,1]
# Out:
# 1.6593954837714555

# %%
df.iat[1,1]
# Out:
# 1.6593954837714555

# %%
import seaborn as sns
df_titanic = sns.load_dataset('titanic')
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df_titanic.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 374         0       3  female   3.0      3      1  21.0750        S  Third
# 302         0       3    male  19.0      0      0   0.0000        S  Third
# 401         0       3    male  26.0      0      0   8.0500        S  Third
# 813         0       3  female   6.0      4      2  31.2750        S  Third
# 691         1       3  female   4.0      0      1  13.4167        C  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 486         1       1  female  35.0      1      0  90.0000        S  First
# 93          0       3    male  26.0      1      2  20.5750        S  Third
# 246         0       3  female  25.0      0      0   7.7750        S  Third
# 104         0       3    male  37.0      2      0   7.9250        S  Third
# 171         0       3    male   4.0      4      1  29.1250        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 374  child       False  NaN  Southampton    no  False
# 302    man        True  NaN  Southampton    no   True
# 401    man        True  NaN  Southampton    no   True
# 813  child       False  NaN  Southampton    no  False
# 691  child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 486  woman       False    C  Southampton   yes  False
# 93     man        True  NaN  Southampton    no  False
# 246  woman       False  NaN  Southampton    no   True
# 104    man        True  NaN  Southampton    no  False
# 171  child       False  NaN   Queenstown    no  False
#
# [100 rows x 15 columns]

# %%
# Code adaption 
df_titanic[df_titanic["fare"] < 5]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 378         0       3  male  20.0      0      0  4.0125        C   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# 674         0       2  male   NaN      0      0  0.0000        S  Second  man
# 732         0       2  male   NaN      0      0  0.0000        S  Second  man
# 806         0       1  male  39.0      0      0  0.0000        S   First  man
# 815         0       1  male   NaN      0      0  0.0000        S   First  man
# 822         0       1  male  38.0      0      0  0.0000        S   First  man
#
#      adult_male deck  embark_town alive  alone
# 179        True  NaN  Southampton    no   True
# 263        True    B  Southampton    no   True
# 271        True  NaN  Southampton   yes   True
# 277        True  NaN  Southampton    no   True
# 302        True  NaN  Southampton    no   True
# 378        True  NaN    Cherbourg    no   True
# 413        True  NaN  Southampton    no   True
# 466        True  NaN  Southampton    no   True
# 481        True  NaN  Southampton    no   True
# 597        True  NaN  Southampton    no   True
# 633        True  NaN  Southampton    no   True
# 674        True  NaN  Southampton    no   True
# 732        True  NaN  Southampton    no   True
# 806        True    A  Southampton    no   True
# 815        True    B  Southampton    no   True
# 822        True  NaN  Southampton    no   True
